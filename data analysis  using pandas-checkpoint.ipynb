# %%
import pandas  #python package....data analysis..
import  numpy
import seaborn

#filtering........pandas......

#visualization....




#loading the dataset into juypter  notebook
#cleaning the data
#visualizing the data
#processing the data
#tranforming the data

# %%
print(dir('pandas'))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
print(dir('numpy'))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
print(dir('seaborn'))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
fortune=pandas.read_csv('f500.csv')

# %%
fortune
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
rev = fortune['revenues']

# %%
#mean calculation
rev.mean()
# Out:
# 55416.358

# %%
rev.max()
# Out:
# 485873

# %%
rev.min()
# Out:
# 21609

# %%
rev.mode()
# Out:
# 0    23044
# 1    29003
# 2    30390
# dtype: int64

# %%
rev.describe()
# Out:
# count       500.000000
# mean      55416.358000
# std       45725.478963
# min       21609.000000
# 25%       29003.000000
# 50%       40236.000000
# 75%       63926.750000
# max      485873.000000
# Name: revenues, dtype: float64

# %%
fortune
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
sec = fortune['sector']

# %%
sec.unique()
# Out:
# array(['Retailing', 'Energy', 'Motor Vehicles & Parts', 'Financials',
#        'Technology', 'Wholesalers', 'Health Care', 'Telecommunications',
#        'Engineering & Construction', 'Industrials', 'Food & Drug Stores',
#        'Aerospace & Defense', 'Food, Beverages & Tobacco',
#        'Household Products', 'Transportation', 'Materials', 'Chemicals',
#        'Media', 'Apparel', 'Hotels, Restaurants & Leisure',
#        'Business Services'], dtype=object)

# %%
len(sec.unique())
# Out:
# 21

# %%
ind = fortune['industry']

# %%
ind.unique()
# Out:
# array(['General Merchandisers', 'Utilities', 'Petroleum Refining',
#        'Motor Vehicles and Parts',
#        'Insurance: Property and Casualty (Stock)',
#        'Computers, Office Equipment', 'Wholesalers: Health Care',
#        'Health Care: Insurance and Managed Care',
#        'Health Care: Pharmacy and Other Services',
#        'Electronics, Electrical Equip.', 'Mining, Crude-Oil Production',
#        'Telecommunications', 'Diversified Financials',
#        'Banks: Commercial and Savings', 'Engineering, Construction',
#        'Insurance: Life, Health (stock)',
#        'Internet Services and Retailing', 'Industrial Machinery',
#        'Food and Drug Stores', 'Trading', 'Specialty Retailers',
#        'Aerospace and Defense', 'Energy', 'Food Consumer Products',
#        'Computer Software', 'Information Technology Services',
#        'Network and Other Communications Equipment',
#        'Insurance: Property and Casualty (Mutual)', 'Pharmaceuticals',
# ...

# %%
len(ind.unique())
# Out:
# 58

# %%
#boolean indexing
fortune[0:5]
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
fortune['company'][0:5]
# Out:
# 0                     Walmart
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# Name: company, dtype: object

# %%
fortune['company'][494:500]
# Out:
# 494    Xinjiang Guanghui Industry Investment
# 495           Teva Pharmaceutical Industries
# 496                 New China Life Insurance
# 497                Wm. Morrison Supermarkets
# 498                                      TUI
# 499                               AutoNation
# Name: company, dtype: object

# %%
fortune['company'][5:10]
# Out:
# 5            Volkswagen
# 6     Royal Dutch Shell
# 7    Berkshire Hathaway
# 8                 Apple
# 9           Exxon Mobil
# Name: company, dtype: object

# %%
fortune['company'][100]
# Out:
# 'China South Industries Group'

# %%
fortune['company'][49]
# Out:
# 'Nippon Telegraph & Telephone'

# %%
fortune['company'][49:51]
# Out:
# 49    Nippon Telegraph & Telephone
# 50            China Life Insurance
# Name: company, dtype: object

# %% [markdown]
# cou = fortune['country']

# %%
fortune['country'].value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# France           29
# Germany          29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# India             7
# Brazil            7
# Italy             7
# Australia         7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Indonesia         1
# Thailand          1
# U.A.E             1
# Saudi Arabia      1
# Belgium           1
# Venezuela         1
# Israel            1
# Turkey            1
# Malaysia          1
# Finland           1
# Norway            1
# Denmark           1
# Luxembourg        1
# Name: country, dtype: int64

# %%
fortune['revenues']
# Out:
# 0      485873
# 1      315199
# 2      267518
# 3      262573
# 4      254694
#         ...
# 495     21903
# 496     21796
# 497     21741
# 498     21655
# 499     21609
# Name: revenues, Length: 500, dtype: int64

# %%
rev = fortune['revenues']
rev.mean()
# Out:
# 55416.358

# %%
#boolen indexing.....
#logical operators...and....list  function.....

#all  the companies rows which  have  earned revenue less the average ...mean..

fortune['revenues']<= fortune['revenues'].mean()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495     True
# 496     True
# 497     True
# 498     True
# 499     True
# Name: revenues, Length: 500, dtype: bool

# %%
fortune[fortune['revenues'] <= fortune['revenues'].mean()]
# Out:
#                               company  rank  revenues  revenue_change  \
# 161  Aviation Industry Corp. of China   162     55306            -8.2
# 162                         ING Group   163     55282           -16.5
# 163    Mitsubishi UFJ Financial Group   164     55185            15.9
# 164              Royal Ahold Delhaize   165     54955            29.7
# 165                            Humana   166     54379             0.2
# ..                                ...   ...       ...             ...
# 495    Teva Pharmaceutical Industries   496     21903            11.5
# 496          New China Life Insurance   497     21796           -13.3
# 497         Wm. Morrison Supermarkets   498     21741           -11.3
# 498                               TUI   499     21655            -5.5
# 499                        AutoNation   500     21609             3.6
#
#      profits   assets  profit_change                 ceo  \
# 161    464.2   124892          -47.4         Tan Ruisong
# ...

# %%
fortune['revenues'].min()
# Out:
# 21609

# %%
fortune['revenues']==fortune['revenues'].max()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: revenues, Length: 500, dtype: bool

# %%
fortune[fortune['revenues'] == fortune['revenues'].max()]
# Out:
#    company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0  Walmart     1    485873             0.8  13643.0  198825           -7.2
#
#                    ceo               industry     sector  previous_rank  \
# 0  C. Douglas McMillon  General Merchandisers  Retailing              1
#
#   country      hq_location                 website  years_on_global_500_list  \
# 0     USA  Bentonville, AR  http://www.walmart.com                        23
#
#    employees  total_stockholder_equity
# 0    2300000                     77798

# %%
fortune[fortune['revenues'] == fortune['revenues'].max()]
# Out:
#    company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0  Walmart     1    485873             0.8  13643.0  198825           -7.2
#
#                    ceo               industry     sector  previous_rank  \
# 0  C. Douglas McMillon  General Merchandisers  Retailing              1
#
#   country      hq_location                 website  years_on_global_500_list  \
# 0     USA  Bentonville, AR  http://www.walmart.com                        23
#
#    employees  total_stockholder_equity
# 0    2300000                     77798

# %%
pro = fortune['profits']
pro.mean()
# Out:
# 3055.203206412828

# %%
fortune[fortune['profits'] > fortune['profits'].mean()]
# Out:
#                company  rank  revenues  revenue_change  profits  assets  \
# 0              Walmart     1    485873             0.8  13643.0  198825
# 1           State Grid     2    315199            -4.4   9571.3  489838
# 4         Toyota Motor     5    254694             7.7  16899.3  437575
# 5           Volkswagen     6    240264             1.5   5937.3  432116
# 6    Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# ..                 ...   ...       ...             ...      ...     ...
# 469        AstraZeneca   470     23002            -6.9   3499.0   62526
# 470              Amgen   471     22991             6.1   7722.0   77626
# 477   Tencent Holdings   478     22871            39.7   6185.9   56968
# 480       U.S. Bancorp   481     22744             5.8   5888.0  445964
# 490      National Grid   491     22036            -3.2  10150.6   82310
#
#      profit_change                  ceo                         industry  \
# ...

# %%
#find the top 18 revenues earings companies names ...and revenues
aa = fortune[fortune['revenues'] <= fortune['revenues'].max()]

# %%
aa[0:10]
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
# 6         Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7        Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                     Apple     9    215639            -7.7  45687.0  321686
# 9               Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 1           -6.2              Kou Wei
# ...

# %%
fortune[fortune['profits'] >= 19316.5]
# Out:
#                                   company  rank  revenues  revenue_change  \
# 7                      Berkshire Hathaway     8    223604             6.1
# 8                                   Apple     9    215639            -7.7
# 14                    Samsung Electronics    15    173957            -2.0
# 21  Industrial & Commercial Bank of China    22    147675           -11.7
# 27                China Construction Bank    28    135093            -8.7
# 37             Agricultural Bank of China    38    117275           -12.1
# 41                          Bank of China    42    113708            -7.1
# 47                      J.P. Morgan Chase    48    105486             4.4
# 60                            Wells Fargo    61     94176             4.6
# 64                               Alphabet    65     90272            20.4
#
#     profits   assets  profit_change                ceo  \
# 7   24074.0   620854            NaN  Warren E. Buffett
# ...

# %%
fortune['profits'].sort_values
# Out:
# <bound method Series.sort_values of 0      13643.0
# 1       9571.3
# 2       1257.9
# 3       1867.5
# 4      16899.3
#         ...
# 495      329.0
# 496      743.9
# 497      406.4
# 498     1151.7
# 499      430.5
# Name: profits, Length: 500, dtype: float64>

# %%
fortune['profits'].sort_values(ascending = False)
# Out:
# 8      45687.0
# 21     41883.9
# 27     34840.9
# 37     27687.8
# 41     24773.4
#         ...
# 148    -6904.0
# 230    -9344.4
# 151   -10256.3
# 327   -13038.0
# 456        NaN
# Name: profits, Length: 500, dtype: float64

# %%
fortune['profits'].sort_values(ascending = False)[0:10]
# Out:
# 8     45687.0
# 21    41883.9
# 27    34840.9
# 37    27687.8
# 41    24773.4
# 47    24733.0
# 7     24074.0
# 60    21938.0
# 64    19478.0
# 14    19316.5
# Name: profits, dtype: float64

# %%
fortune['profits'].describe()
# Out:
# count      499.000000
# mean      3055.203206
# std       5171.981071
# min     -13038.000000
# 25%        556.950000
# 50%       1761.600000
# 75%       3954.000000
# max      45687.000000
# Name: profits, dtype: float64

# %%
print('naveen reddy python videos')
# Out:
# naveen reddy python videos

# %%
ass = fortune['assets']

# %%
#find the least 10 assests earing companies.....and revenues 
aa = fortune [fortune['assets'] <= fortune['assets']. min()]

# %%
aa[0:10]
# Out:
#             company  rank  revenues  revenue_change  profits  assets  \
# 294  Rajesh Exports   295     36114            43.1    185.8    3717
#
#      profit_change              ceo industry       sector  previous_rank  \
# 294           13.8  Rajesh J. Mehta  Trading  Wholesalers            423
#
#     country       hq_location                     website  \
# 294   India  Bengaluru, India  http://www.rajeshindia.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# 294                         2        328                       868

# %%
fortune['assets'].sort_values()
# Out:
# 294       3717
# 456       4982
# 401       5413
# 438       6093
# 308       6921
#         ...
# 163    2722354
# 37     2816039
# 27     3016578
# 45     3287968
# 21     3473238
# Name: assets, Length: 500, dtype: int64

# %%
fortune['assets'].sort_values(ascending = True)
# Out:
# 294       3717
# 456       4982
# 401       5413
# 438       6093
# 308       6921
#         ...
# 163    2722354
# 37     2816039
# 27     3016578
# 45     3287968
# 21     3473238
# Name: assets, Length: 500, dtype: int64

# %%
fortune['assets'].sort_values(ascending = True)[0:10]
# Out:
# 294    3717
# 456    4982
# 401    5413
# 438    6093
# 308    6921
# 486    7426
# 411    7932
# 474    8945
# 402    9292
# 488    9362
# Name: assets, dtype: int64

# %%
fortune[fortune['assets'] <= 9362]
# Out:
#                                 company  rank  revenues  revenue_change  \
# 294                      Rajesh Exports   295     36114            43.1
# 308                      Edeka Zentrale   309     34193             6.8
# 401                 World Fuel Services   402     27016           -11.1
# 402                Phoenix Pharmahandel   403     26976             5.2
# 411                           Tech Data   412     26235            -0.5
# 438  China National Aviation Fuel Group   439     24588            11.3
# 456                     Heraeus Holding   457     23793            65.9
# 474                    US Foods Holding   475     22919            -0.9
# 486                   Ultrapar Holdings   487     22167            -2.3
# 488                      Sears Holdings   489     22138           -12.0
#
#      profits  assets  profit_change                  ceo  \
# 294    185.8    3717           13.8      Rajesh J. Mehta
# 308    356.0    6921           28.3          Markus Mosa
# ...

# %%
type(fortune)
# Out:
# pandas.core.frame.DataFrame

# %%
#steps in data science proect....

.........loading the data ...in your  python environment ..
....describe().....descriptive statstics...max,min,mean,sd,count......
....filter out or boolen indexing  to understand our data
....visualize  the data .....charts..plots...

      2dim piot.....
      ...scatterplot...x and y axis...
      ...line  plot...
      ...histogram...
      ...bar plot..
     ....box plot 
        
.....check our statistics... hypothesis testing  ..on our data  ...assumptions..

.....check which model to use for prediction..

.....apply  ml to the data...

.....accuracy of your model.... 
        
    if model is performing well ... retain that model..
       other if accuracy  is bad ... with this model..
       apply another ml model ... checl ... accuracy of that model...

# %% [markdown]
# ##  visualization ...different types of plots...

# %%
#matplotlib.pyplot...

#matlab..research field...
#matplotlib... visualzation.....matplotlib.pyplot...

# %%
import matplotlib.pyplot as plt

# %%
fortune.head(15)
# Out:
#                      company  rank  revenues  revenue_change  profits  assets  \
# 0                    Walmart     1    485873             0.8  13643.0  198825
# 1                 State Grid     2    315199            -4.4   9571.3  489838
# 2              Sinopec Group     3    267518            -9.1   1257.9  310726
# 3   China National Petroleum     4    262573           -12.3   1867.5  585619
# 4               Toyota Motor     5    254694             7.7  16899.3  437575
# 5                 Volkswagen     6    240264             1.5   5937.3  432116
# 6          Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7         Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                      Apple     9    215639            -7.7  45687.0  321686
# 9                Exxon Mobil    10    205004           -16.7   7840.0  330314
# 10                  McKesson    11    198533             3.1   5070.0   60969
# ...

# %%
fortune.tail(110)
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 390                 Westpac Banking   391     27704           -10.8   5477.0
# 391                      Coop Group   392     27669             2.8    482.1
# 392                        Facebook   393     27638            54.2  10217.0
# 393                  Travelers Cos.   394     27625             3.1   3014.0
# 394           Capital One Financial   395     27519             9.6   3751.0
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
print(fortune.columns)
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
#visualization...
